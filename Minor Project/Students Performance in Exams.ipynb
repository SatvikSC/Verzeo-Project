# %% [markdown]
# # Students Performance in Exams
#
#
# # Minor Project (ML-July-B2)

# %% [markdown]
# ----

# %% [markdown]
# In this project we will discuss various aspect of data and how to explore it with EDA methods

# %% [markdown]
# ## Objective of this Analysis:
# To understand the how the student's performance (test scores) is affected by the other variables (Gender, Ethnicity, Parental level of education, Lunch, Test preparation course).

# %% [markdown]
#                                                  Some information about columns of dataset
#
# |Columns|Column Details|
# |------|------|
# |Gender                       | Gender of the student                                                 |
# |Race/ethnicity               | Race of the Student As Group A/B/C                                    |
# |Parental level of education  | What is the education Qualification of Students Parent                |
# |Lunch                        | Whether the lunch is Standard type/Free lunch or Some discounted lunch|
# |Test preparation course      | Whether Student has Taken or not and Completed                        |
# |Math score                   | Scores in Maths                                                       |
# |Reading score                | Scores in Reading                                                     |
# |Writing score                | Scores in Writing                                                     |

# %% [markdown]
# ### What to do in  Exploratory Data Analysis:
# 1.To Analyse insights in the dataset.\
# 2.To understand the connection between the variables and to uncover the underlying structure\
# 3.To extract the important Variables.\
# 4.To test the underlying assumptions.\
# 5.Provide Insights with Suitable Graphs and Visualizations.\
# 6.Write all your inferences with supporting Analysis and Visualizations.

# %% [markdown]
# ----

# %% [markdown]
# ## Let's import the required Libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %% [markdown]
# *Importing Dataset*\
# (Reading the data set)

# %%
df = pd.read_csv('StudentsPerformance.csv')
df.head()
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
#
#   test preparation course  math score  reading score  writing score
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93
# 3                    none          47             57             44
# 4                    none          76             78             75

# %% [markdown]
# ### Number of Rows and Columns

# %%
df.shape
# Out:
# (1000, 8)

# %% [markdown]
# *This tells there are 1000 rows and 8 columns*

# %% [markdown]
# ### Let us check if the data has some missing values.

# %%
df.isnull().sum()
# Out:
# gender                         0
# race/ethnicity                 0
# parental level of education    0
# lunch                          0
# test preparation course        0
# math score                     0
# reading score                  0
# writing score                  0
# dtype: int64

# %% [markdown]
# *So there are no missing values in the dataset.*

# %% [markdown]
# ### Let us check the datatype of all the column values.

# %%
df.dtypes
# Out:
# gender                         object
# race/ethnicity                 object
# parental level of education    object
# lunch                          object
# test preparation course        object
# math score                      int64
# reading score                   int64
# writing score                   int64
# dtype: object

# %% [markdown]
# **Let us analyze the values of the columns and check whether they are numerical or categorical.**

# %%
df['gender'].value_counts()
# Out:
# female    518
# male      482
# Name: gender, dtype: int64

# %%
df['parental level of education'].value_counts()
# Out:
# some college          226
# associate's degree    222
# high school           196
# some high school      179
# bachelor's degree     118
# master's degree        59
# Name: parental level of education, dtype: int64

# %%
df['race/ethnicity'].value_counts()
# Out:
# group C    319
# group D    262
# group B    190
# group E    140
# group A     89
# Name: race/ethnicity, dtype: int64

# %%
df['lunch'].value_counts()
# Out:
# standard        645
# free/reduced    355
# Name: lunch, dtype: int64

# %%
df['test preparation course'].value_counts()
# Out:
# none         642
# completed    358
# Name: test preparation course, dtype: int64

# %% [markdown]
# From the above we understand that column, \
# **“gender”, \
# “parental level of education”,\
# “race/ethnicity”, \
# “lunch”, \
# “test preparation course”**\
# all are categorical variables.

# %% [markdown]
# And as we know marks are always numerical in category, therefore the columns, \
# **“math score”, \
# “read score”, \
# “write score”**\
# contain numerical values and hence are numerical variables.

# %% [markdown]
# ### Lets see what our data describe

# %%
df.describe()
# Out:
#        math score  reading score  writing score
# count  1000.00000    1000.000000    1000.000000
# mean     66.08900      69.169000      68.054000
# std      15.16308      14.600192      15.195657
# min       0.00000      17.000000      10.000000
# 25%      57.00000      59.000000      57.750000
# 50%      66.00000      70.000000      69.000000
# 75%      77.00000      79.000000      79.000000
# max     100.00000     100.000000     100.000000

# %% [markdown]
# Here we can see the descriptive statistics of numerical variables \
# **Math score, \
# Reading score and \
# Writing score**\
# [such as *total count, mean, standard deviation, minimum and maximum values and three quantiles* of the data (25%,50%,75%)].

# %%
df.describe(include = 'all').iloc[:4,:5]
# Out:
#         gender race/ethnicity parental level of education     lunch  \
# count     1000           1000                        1000      1000
# unique       2              5                           6         2
# top     female        group C                some college  standard
# freq       518            319                         226       645
#
#        test preparation course
# count                     1000
# unique                       2
# top                       none
# freq                       642

# %% [markdown]
# Here we can see some more information about categorical variables\
# **Gender, \
# Race/ethnicity, \
# Parental level of education, \
# Lunch and \
# Test preparation course**\
# [such as number of *unique* values, maxi. occuring value(*top*), its *frequancy*]

# %% [markdown]
# **Lets add some more columns for further calculations**

# %%
df['average'] = (df['math score'] + df['reading score'] + df['writing score']) /3

# %%
plt.figure(figsize=(15,5))
plt.subplots_adjust(wspace=0.5, hspace=0.2)

plt.subplot(1,3,1)
plt.title('Math Scores')
sns.boxplot(y='math score',data=df,color='m',linewidth=2)
plt.subplot(1,3,2)
plt.title('Reading Scores')
sns.boxplot(y='reading score',data=df,color='g',linewidth=2)
plt.subplot(1,3,3)
plt.title('Writing Scores')
sns.boxplot(y='writing score',data=df,color='r',linewidth=2)
plt.show()

# %% [markdown]
# *From about, we can observ that maximum students score between 60-80 in all subject*

# %% [markdown]
# ## Distribution graphs for [ Maths, Reading, Writing and Average]

# %%
plt.figure(figsize = (15,8))
plt.subplots_adjust(wspace=0.5, hspace=0.2)

plt.subplot(2,2,1)
sns.distplot(df['math score'],color ='y')
plt.subplot(2,2,2)
sns.distplot(df['reading score'],color ='r')
plt.subplot(2,2,3)
sns.distplot(df['writing score'],color ='g')
plt.subplot(2,2,4)
sns.distplot(df['average'],color ='b')
plt.show()

# %%
sns.pairplot(df)

# %% [markdown]
# The above plots are Paired-plots, these graphs are ploted w.r.t. each other(only numeric variables)\
#
# \
# **After ploting these graphs we can conclude that are data is normally distributed**

# %% [markdown]
# ## Analyze average scores on the basis of categorical variables
# **[ Gender, Race/Ethnicity, Parental Level of Education, Test Preparation Course” ]**

# %%
sns.barplot(df['gender'], df['average'])

# %%
sns.barplot(df['race/ethnicity'], df['average'])

# %%
sns.barplot(df['parental level of education'], df['average'])
plt.xticks(rotation=20)
# Out:
# (array([0, 1, 2, 3, 4, 5]), <a list of 6 Text xticklabel objects>)

# %%
sns.barplot(df['test preparation course'], df['average'])

# %% [markdown]
# ### Let us the analyze the data on the basis of the no. of students [Failed / Passed in exam].

# %%
df['math_PassStatus'] = np.where(df['math score']<40, 'Fail', 'Pass')
df['read_PassStatus'] = np.where(df['reading score']<40, 'Fail', 'Pass')
df['write_PassStatus'] = np.where(df['writing score']<40, 'Fail', 'Pass')

# %%
plt.figure(figsize=(18,5))
# plt.subplots_adjust(hspace=0.2)

plt.subplot(1,3,1)
sns.countplot(x='parental level of education', data = df, hue='math_PassStatus',palette = 'muted')
plt.xticks(rotation='40')
plt.subplot(1,3,2)
plt.title('Comparision of parental level of education w.r.t to student\'s Pass / Fail status', fontweight = 30, fontsize = 20)
sns.countplot(x='parental level of education', data = df, hue='read_PassStatus',palette = 'muted')
plt.xticks(rotation='40')
plt.subplot(1,3,3)
sns.countplot(x='parental level of education', data = df, hue='write_PassStatus',palette = 'muted')
plt.xticks(rotation='40')
;
# Out:
# ''

# %%
plt.figure(figsize=(18,5))
# plt.subplots_adjust(hspace=0.2)

plt.subplot(1,3,1)
sns.countplot(x='test preparation course', data = df, hue='math_PassStatus',palette = 'muted')
plt.subplot(1,3,2)
plt.title('Comparision of Test prepration w.r.t to Pass / Fail status', fontweight = 30, fontsize = 20)
sns.countplot(x='test preparation course', data = df, hue='read_PassStatus',palette = 'muted')
plt.subplot(1,3,3)
sns.countplot(x='test preparation course', data = df, hue='write_PassStatus',palette = 'muted')
;
# Out:
# ''

# %%
plt.figure(figsize=(18,5))
# plt.subplots_adjust(hspace=0.2)

plt.subplot(1,3,1)
sns.countplot(x='race/ethnicity', data = df, hue='math_PassStatus',palette = 'muted')
plt.xticks(rotation='30')
plt.subplot(1,3,2)
plt.title('Comparision of Ethics group w.r.t to Pass / Fail', fontweight = 30, fontsize = 20)
sns.countplot(x='race/ethnicity', data = df, hue='read_PassStatus',palette = 'muted')
plt.xticks(rotation='30')
plt.subplot(1,3,3)
sns.countplot(x='race/ethnicity', data = df, hue='write_PassStatus',palette = 'muted')
plt.xticks(rotation='30')
;
# Out:
# ''

# %% [markdown]
# ### Comparison of Parental level of education and Test prepration overall

# %%
plt.rcParams['figure.figsize'] = (15, 9)
sns.countplot(x = 'parental level of education', data = df, hue = 'test preparation course', palette = 'dark')
plt.title('Parental Education vs Test Preparation Course', fontweight = 30, fontsize = 20)
plt.show()

# %% [markdown]
# ### Comparison of Race/Ethnicity and Parental level of education

# %%
plt.rcParams['figure.figsize'] = (15, 9)
x = pd.crosstab(df['race/ethnicity'], df['parental level of education'])
x.div(x.sum(1).astype(float), axis = 0).plot(kind = 'bar', stacked = 'True')
plt.title('Race vs Parental Education', fontweight = 30, fontsize = 20)
plt.show()

# %% [markdown]
# ### Comparison of race/ethnicity and test preparation course

# %%
sns.countplot(x = 'race/ethnicity', data = df,  hue = 'test preparation course', palette = 'bright')
plt.title('Race vs Test Preparion', fontweight = 30, fontsize = 20)
plt.show()

# %% [markdown]
# **Lets See the overall overview of _Gender,Ethinicity, Lunch, Parentel level of Education_**

# %%
plt.figure(figsize=(20,15))
plt.subplots_adjust(wspace=0.5, hspace=0.2)

plt.subplot(141)
plt.title('Gender',fontsize = 20)
df['gender'].value_counts().plot.pie(autopct="%1.1f%%")

plt.subplot(142)
plt.title('Ethinicity',fontsize = 20)
df['race/ethnicity'].value_counts().plot.pie(autopct="%1.1f%%")

plt.subplot(143)
plt.title('Lunch',fontsize = 20)
df['lunch'].value_counts().plot.pie(autopct="%1.1f%%")

plt.subplot(144)
plt.title('Parentel level of Education',fontsize = 20)
df['parental level of education'].value_counts().plot.pie(autopct="%1.1f%%")
plt.show()

# %% [markdown]
# **Observations:**
# <li>The proportion of male and female are almost same
# <li>Highest number of students belong to Group C ethinicity followed by Group D
# <li>Highest proportion of the students have standard lunch
# <li>Highest proportion of parentel level of Education is 'Some college', 'associate's degreee' and 'high school'

# %% [markdown]
# ---

# %% [markdown]
# **1. Lets look at the scores of male and female students seperately in each subject.**

# %%
plt.figure(figsize=(15,5))
plt.subplots_adjust(left=0.125, bottom=0.1, right=0.9, top=0.9,
                      wspace=0.5, hspace=0.2)
plt.subplot(131)
plt.title('Math Scores')
sns.barplot(x="gender", y="math score", data=df)
plt.subplot(132)
plt.title('Reading Scores')
sns.barplot(x="gender", y="reading score", data=df)
plt.subplot(133)
plt.title('Writing Scores')
sns.barplot(x="gender", y="writing score", data=df)
plt.show()

# %% [markdown]
# We can see that male students scored higher in Maths where as female students scored higher in Reading and writing
#
#
# \
# **2. Lets look at the scores who completed Test preperation course**

# %%
plt.figure(figsize=(15,5))
plt.subplots_adjust(left=0.125, bottom=0.1, right=0.9, top=0.9,
                      wspace=0.5, hspace=0.2)
plt.subplot(131)
plt.title('Math Scores')
sns.barplot(hue="gender", y="math score", x="test preparation course", data=df)
plt.subplot(132)
plt.title('Reading Scores')
sns.barplot(hue="gender", y="reading score", x="test preparation course", data=df)
plt.subplot(133)
plt.title('Writing Scores')
sns.barplot(hue="gender", y="writing score", x="test preparation course", data=df)
plt.show()

# %% [markdown]
# So the students (male and female) who completed the test preparation course scored higher in all three subjects.
#
#
# \
# **3. Lets look at the scores of the students of different group who completed test preperation course.**

# %%
plt.figure(figsize=(15,5))
plt.subplots_adjust(left=0.125, bottom=0.1, right=0.9, top=0.9,
                      wspace=0.5, hspace=0.2)
plt.subplot(131)
plt.title('Math Scores')
sns.barplot(x="race/ethnicity", y="math score", hue="test preparation course", data=df)
plt.subplot(132)
plt.title('Reading Scores')
sns.barplot(hue="test preparation course", y="reading score", x="race/ethnicity", data=df)
plt.subplot(133)
plt.title('Writing Scores')
sns.barplot(hue="test preparation course", y="writing score", x= 'race/ethnicity',data=df)

plt.show()

# %% [markdown]
# Highest no. of Students who belongs to Group E has completed the test preperation course in Math and Reading and scored highest.
#
# Highest no. of Students who belongs to Group D and E has completed the test preperation course in Writing and scored highest.

# %% [markdown]
# ---

# %% [markdown]
# ### Now lets analyze the relation between Test preperation course and other variables

# %%
plt.figure(figsize=(30,15))
plt.subplots_adjust(left=0.125, bottom=0.1, right=0.9, top=0.9,
                      wspace=0.5, hspace=0.2)
plt.subplot(251)
plt.title('Test Preparation course Vs Gender',fontsize = 15)
sns.countplot(hue="test preparation course", x="gender", data=df)

plt.subplot(254)
plt.title('Test Preparation course Vs Parental Level Of Education',fontsize = 15)
sns.countplot(hue="test preparation course", y="parental level of education", data=df)

plt.subplot(253)
plt.title('Test Preparation course Vs Lunch',fontsize = 15)
sns.countplot(hue="test preparation course", x="lunch", data=df)

plt.subplot(252)
plt.title('Test Preparation course Vs Ethnicity',fontsize = 15)
sns.countplot(hue="test preparation course", y="race/ethnicity", data=df)

plt.show()

# %% [markdown]
# **Observations:**
# <li>Most of the students have not completed the test preparation course.
# <li>Highest number Students who belong to group C ethinicity have completed the test preparation course.
# <li>Standard lunch students have completed the test preparation course
# <LI>Students whos parental level of education is 'some college, 'associate's degree', and high school have completed the test preparation course.
#
#
# \
# We can also say that the students who belongs to Group E ethincity has scored more marks in all three subjectes even though they have not completed the test preparation course.

# %% [markdown]
# ---

# %% [markdown]
# ### To analyse the data in more deeper way, lets few new columns: Total marks, Percentage and Grades

# %%
df['total marks']=df['math score']+df['reading score']+df['writing score']
df['percentage']=df['total marks']/300*100

# %% [markdown]
# **Lets assign grades.**\
# Criteria of the grades are as follows:
#
# 85-100 : Grade A\
# 70-84 : Grade B\
# 55-69 : Grade C\
# 35-54 : Grade D\
# 0-35 : Grade E

# %%
def determine_grade(scores):
    if scores >= 85 and scores <= 100:
        return 'Grade A'
    elif scores >= 70 and scores < 85:
        return 'Grade B'
    elif scores >= 55 and scores < 70:
        return 'Grade C'
    elif scores >= 35 and scores < 55:
        return 'Grade D'
    elif scores >= 0 and scores < 35:
        return 'Grade E'
    
df['grades']=df['percentage'].apply(determine_grade)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 15 columns):
# gender                         1000 non-null object
# race/ethnicity                 1000 non-null object
# parental level of education    1000 non-null object
# lunch                          1000 non-null object
# test preparation course        1000 non-null object
# math score                     1000 non-null int64
# reading score                  1000 non-null int64
# writing score                  1000 non-null int64
# average                        1000 non-null float64
# math_PassStatus                1000 non-null object
# read_PassStatus                1000 non-null object
# write_PassStatus               1000 non-null object
# total marks                    1000 non-null int64
# percentage                     1000 non-null float64
# grades                         1000 non-null object
# dtypes: float64(2), int64(4), object(9)
# memory usage: 117.3+ KB

# %%
df['grades'].value_counts().plot.pie(autopct="%1.1f%%")
plt.show()
print("Most of the students got Grade B and Grade C.")
# Out:
# Most of the students got Grade B and Grade C.

# %% [markdown]
# ### Now, lets see the relation between the remaining variables

# %%
plt.title('Gender Vs Ethnicity',fontsize = 20)
sns.countplot(x="gender", hue="race/ethnicity", data=df)
plt.show()

# %%
pr=pd.crosstab(df['race/ethnicity'],df['parental level of education'],normalize=0)

pr.plot.barh(stacked=True)
plt.title('Ethinicity Vs Parental Level of Education',fontsize = 20)
plt.show()

# %%
plt.figure(figsize=(40,10))
plt.subplots_adjust(left=0.125, bottom=0.1, right=0.9, top=0.9,
                      wspace=0.5, hspace=0.2)
plt.subplot(251)
plt.title('Parental education and Gender',fontsize=15)
sns.countplot(hue="parental level of education", x="gender", data=df)
plt.subplot(252)
plt.title('Parental education and Lunch',fontsize=15)
sns.countplot(hue="parental level of education", x="lunch", data=df)

plt.show()

# %%
plt.figure(figsize=(40,10))
plt.subplots_adjust(left=0.125, bottom=0.1, right=0.9, top=0.9,
                      wspace=0.5, hspace=0.2)
plt.subplot(251)
plt.title('Lunch and Gender',fontsize=15)
sns.countplot(x="lunch", hue="gender", data=df)
plt.subplot(252)
plt.title('Ethinicity and Lunch',fontsize=15)
sns.countplot(x="race/ethnicity", hue="lunch", data=df)
plt.show()

# %%
plt.title('Grades and Parental level of Education',fontsize=20)
sns.countplot(x="parental level of education", hue="grades", data=df)
plt.show()

# %%
plt.title('Grades and Ethinicity',fontsize=20)
sns.countplot(x="race/ethnicity", hue="grades", data=df)

# %%
gr=pd.crosstab(df['grades'],df['race/ethnicity'],normalize=0) #normalized values 
gr.plot.barh(stacked=True)
plt.title('Grades and Ethinicity',fontsize=20)
plt.show()
